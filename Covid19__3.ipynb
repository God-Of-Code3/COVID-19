# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import matplotlib
matplotlib.use("Agg")
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from keras.models import Sequential
from keras.layers.core import Dense
from keras.optimizers import SGD
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import random
import pickle
import cv2
import os
import nibabel as nib
from scipy import ndimage
import tensorflow as tf

from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint

# %%
MAIN_PATH = "/content/drive/My Drive/Dataset/"
DATASET_PATH = MAIN_PATH + "Data/"
HEALTHY_PATH = DATASET_PATH + "healthy/"
SICK_PATH = DATASET_PATH + "sick/"
TEST_PATH = DATASET_PATH + "test/"

COMP_PATH = MAIN_PATH + "Computed/"
HEALTHY_PATH2 = COMP_PATH + "healthy/"
SICK_PATH2 = COMP_PATH + "sick/"

# %%
random.seed(49)
Healthy_Paths = os.listdir(HEALTHY_PATH)
Healthy_Paths = list(map(lambda x: "healthy/" + x, Healthy_Paths))
Sick_Paths = os.listdir(SICK_PATH)
Sick_Paths = list(map(lambda x: "sick/" + x, Sick_Paths))
random.shuffle(Sick_Paths)
random.shuffle(Healthy_Paths)
Paths = Healthy_Paths + Sick_Paths[:204]
random.shuffle(Paths)

data = []
labels = []
min_height = -1

# %%
random.seed(49)
Healthy_Paths = os.listdir(HEALTHY_PATH2)
Healthy_Paths = list(map(lambda x: "healthy/" + x, Healthy_Paths))
Sick_Paths = os.listdir(SICK_PATH2)
Sick_Paths = list(map(lambda x: "sick/" + x, Sick_Paths))
random.shuffle(Sick_Paths)
random.shuffle(Healthy_Paths)
Paths = Healthy_Paths + Sick_Paths[:204]
random.shuffle(Paths)

data = []
labels = []
min_height = -1

# %%
def normalize(volume):
    min = -1000
    max = 400
    volume[volume < min] = min
    volume[volume > max] = max
    volume = (volume - min) / (max - min)
    volume = volume.astype("float32")
    return volume


def resize_volume(img):
    desired_depth = 32
    desired_width = 128
    desired_height = 128
    current_depth = img.shape[-1]
    current_width = img.shape[0]
    current_height = img.shape[1]
    depth = current_depth / desired_depth
    width = current_width / desired_width
    height = current_height / desired_height
    depth_factor = 1 / depth
    width_factor = 1 / width
    height_factor = 1 / height
    img = ndimage.rotate(img, 90, reshape=False)
    img = ndimage.zoom(img, (width_factor, height_factor, depth_factor), order=1)
    return img
  

def process_scan(volume):
    volume = normalize(volume)
    volume = resize_volume(volume)
    return volume

def rotate(volume):
    def scipy_rotate(volume):
        angles = [-20, -10, -5, 5, 10, 20]
        angle = random.choice(angles)
        volume = ndimage.rotate(volume, angle, reshape=False)
        volume[volume < 0] = 0
        volume[volume > 1] = 1
        return volume

    augmented_volume = tf.numpy_function(scipy_rotate, [volume], tf.float32)
    return augmented_volume


def train_preprocessing(volume, label):
    volume = rotate(volume)
    volume = tf.expand_dims(volume, axis=3)
    return volume, label


def validation_preprocessing(volume, label):
    volume = tf.expand_dims(volume, axis=3)
    return volume, label

# %%
COMPRESSION = 4

for i, file_path in enumerate(Paths):
  img = nib.load(DATASET_PATH + file_path)
  img = img.get_fdata()
  img = process_scan(img)
  new_img = []
  new_img = np.array(img, dtype="float")
  new_img = tf.expand_dims(new_img, axis=3)
  data.append(new_img)
  with open(MAIN_PATH + "Computed/" + file_path + ".pickle", 'wb') as f:
    pickle.dump([new_img], f)
  label = file_path.split("/")[0]

  if label == "sick":
    label = [1, 0]
  else:
    label = [0, 1]
  labels.append(label)

  if min_height == -1 or img.shape[2] < min_height:
    min_height = img.shape[2]
  print(str(i) + "/408 computed")
print(data[0].shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/nibabel/loadsave.py in load(filename, **kwargs)
#      41     try:
# ---> 42         stat_result = os.stat(filename)
#      43     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/Dataset/Data/sick/bde6950a08cb730292f6c0c832cdcd7e.nii.gz.pickle'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-46352d567e1a> in <module>()
#       2
#       3 for i, file_path in enumerate(Paths):
# ----> 4   img = nib.load(DATASET_PATH + file_path)
#       5   img = img.get_fdata()
#       6   img = process_scan(img)
#
# /usr/local/lib/python3.6/dist-packages/nibabel/loadsave.py in load(filename, **kwargs)
#      42         stat_result = os.stat(filename)
#      43     except OSError:
# ---> 44         raise FileNotFoundError("No such file or no access: '%s'" % filename)
#      45     if stat_result.st_size <= 0:
#      46         raise ImageFileError("Empty file: '%s'" % filename)
#
# FileNotFoundError: No such file or no access: '/content/drive/My Drive/Dataset/Data/sick/bde6950a08cb730292f6c0c832cdcd7e.nii.gz.pickle'

# %%
COMPRESSION = 4

for i, file_path in enumerate(Paths):
  with open(COMP_PATH + file_path, 'rb') as f:
    new_img = pickle.load(f)
    new_img = rotate(new_img)
    data.append(new_img[0])
  label = file_path.split("/")[0]
  if label == "sick":
    label = [1, 0]
  else:
    label = [0, 1]
  labels.append(label)
  print(str(i) + "/408 computed")
# Out:
# 0/408 computed
# 1/408 computed
# 2/408 computed
# 3/408 computed
# 4/408 computed
# 5/408 computed
# 6/408 computed
# 7/408 computed
# 8/408 computed
# 9/408 computed
# 10/408 computed
# 11/408 computed
# 12/408 computed
# 13/408 computed
# 14/408 computed
# 15/408 computed
# 16/408 computed
# 17/408 computed
# 18/408 computed
# 19/408 computed
# 20/408 computed
# 21/408 computed
# 22/408 computed
# 23/408 computed
# 24/408 computed
# 25/408 computed
# 26/408 computed
# 27/408 computed
# 28/408 computed
# 29/408 computed
# 30/408 computed
# 31/408 computed
# 32/408 computed
# 33/408 computed
# 34/408 computed
# 35/408 computed
# 36/408 computed
# 37/408 computed
# 38/408 computed
# 39/408 computed
# 40/408 computed
# 41/408 computed
# 42/408 computed
# 43/408 computed
# 44/408 computed
# 45/408 computed
# 46/408 computed
# 47/408 computed
# 48/408 computed
# 49/408 computed
# 50/408 computed
# 51/408 computed
# 52/408 computed
# 53/408 computed
# 54/408 computed
# 55/408 computed
# 56/408 computed
# 57/408 computed
# 58/408 computed
# 59/408 computed
# 60/408 computed
# 61/408 computed
# 62/408 computed
# 63/408 computed
# 64/408 computed
# 65/408 computed
# 66/408 computed
# 67/408 computed
# 68/408 computed
# 69/408 computed
# 70/408 computed
# 71/408 computed
# 72/408 computed
# 73/408 computed
# 74/408 computed
# 75/408 computed
# 76/408 computed
# 77/408 computed
# 78/408 computed
# 79/408 computed
# 80/408 computed
# 81/408 computed
# 82/408 computed
# 83/408 computed
# 84/408 computed
# 85/408 computed
# 86/408 computed
# 87/408 computed
# 88/408 computed
# 89/408 computed
# 90/408 computed
# 91/408 computed
# 92/408 computed
# 93/408 computed
# 94/408 computed
# 95/408 computed
# 96/408 computed
# 97/408 computed
# 98/408 computed
# 99/408 computed
# 100/408 computed
# 101/408 computed
# 102/408 computed
# 103/408 computed
# 104/408 computed
# 105/408 computed
# 106/408 computed
# 107/408 computed
# 108/408 computed
# 109/408 computed
# 110/408 computed
# 111/408 computed
# 112/408 computed
# 113/408 computed
# 114/408 computed
# 115/408 computed
# 116/408 computed
# 117/408 computed
# 118/408 computed
# 119/408 computed
# 120/408 computed
# 121/408 computed
# 122/408 computed
# 123/408 computed
# 124/408 computed
# 125/408 computed
# 126/408 computed
# 127/408 computed
# 128/408 computed
# 129/408 computed
# 130/408 computed
# 131/408 computed
# 132/408 computed
# 133/408 computed
# 134/408 computed
# 135/408 computed
# 136/408 computed
# 137/408 computed
# 138/408 computed
# 139/408 computed
# 140/408 computed
# 141/408 computed
# 142/408 computed
# 143/408 computed
# 144/408 computed
# 145/408 computed
# 146/408 computed
# 147/408 computed
# 148/408 computed
# 149/408 computed
# 150/408 computed
# 151/408 computed
# 152/408 computed
# 153/408 computed
# 154/408 computed
# 155/408 computed
# 156/408 computed
# 157/408 computed
# 158/408 computed
# 159/408 computed
# 160/408 computed
# 161/408 computed
# 162/408 computed
# 163/408 computed
# 164/408 computed
# 165/408 computed
# 166/408 computed
# 167/408 computed
# 168/408 computed
# 169/408 computed
# 170/408 computed
# 171/408 computed
# 172/408 computed
# 173/408 computed
# 174/408 computed
# 175/408 computed
# 176/408 computed
# 177/408 computed
# 178/408 computed
# 179/408 computed
# 180/408 computed
# 181/408 computed
# 182/408 computed
# 183/408 computed
# 184/408 computed
# 185/408 computed
# 186/408 computed
# 187/408 computed
# 188/408 computed
# 189/408 computed
# 190/408 computed
# 191/408 computed
# 192/408 computed
# 193/408 computed
# 194/408 computed
# 195/408 computed
# 196/408 computed
# 197/408 computed
# 198/408 computed
# 199/408 computed
# 200/408 computed
# 201/408 computed
# 202/408 computed
# 203/408 computed
# 204/408 computed
# 205/408 computed
# 206/408 computed
# 207/408 computed
# 208/408 computed
# 209/408 computed
# 210/408 computed
# 211/408 computed
# 212/408 computed
# 213/408 computed
# 214/408 computed
# 215/408 computed
# 216/408 computed
# 217/408 computed
# 218/408 computed
# 219/408 computed
# 220/408 computed
# 221/408 computed
# 222/408 computed
# 223/408 computed
# 224/408 computed
# 225/408 computed
# 226/408 computed
# 227/408 computed
# 228/408 computed
# 229/408 computed
# 230/408 computed
# 231/408 computed
# 232/408 computed
# 233/408 computed
# 234/408 computed
# 235/408 computed
# 236/408 computed
# 237/408 computed
# 238/408 computed
# 239/408 computed
# 240/408 computed
# 241/408 computed
# 242/408 computed
# 243/408 computed
# 244/408 computed
# 245/408 computed
# 246/408 computed
# 247/408 computed
# 248/408 computed
# 249/408 computed
# 250/408 computed
# 251/408 computed
# 252/408 computed
# 253/408 computed
# 254/408 computed
# 255/408 computed
# 256/408 computed
# 257/408 computed
# 258/408 computed
# 259/408 computed
# 260/408 computed
# 261/408 computed
# 262/408 computed
# 263/408 computed
# 264/408 computed
# 265/408 computed
# 266/408 computed
# 267/408 computed
# 268/408 computed
# 269/408 computed
# 270/408 computed
# 271/408 computed
# 272/408 computed
# 273/408 computed
# 274/408 computed
# 275/408 computed
# 276/408 computed
# 277/408 computed
# 278/408 computed
# 279/408 computed
# 280/408 computed
# 281/408 computed
# 282/408 computed
# 283/408 computed
# 284/408 computed
# 285/408 computed
# 286/408 computed
# 287/408 computed
# 288/408 computed
# 289/408 computed
# 290/408 computed
# 291/408 computed
# 292/408 computed
# 293/408 computed
# 294/408 computed
# 295/408 computed
# 296/408 computed
# 297/408 computed
# 298/408 computed
# 299/408 computed
# 300/408 computed
# 301/408 computed
# 302/408 computed
# 303/408 computed
# 304/408 computed
# 305/408 computed
# 306/408 computed
# 307/408 computed
# 308/408 computed
# 309/408 computed
# 310/408 computed
# 311/408 computed
# 312/408 computed
# 313/408 computed
# 314/408 computed
# 315/408 computed
# 316/408 computed
# 317/408 computed
# 318/408 computed
# 319/408 computed
# 320/408 computed
# 321/408 computed
# 322/408 computed
# 323/408 computed
# 324/408 computed
# 325/408 computed
# 326/408 computed
# 327/408 computed
# 328/408 computed
# 329/408 computed
# 330/408 computed
# 331/408 computed
# 332/408 computed
# 333/408 computed
# 334/408 computed
# 335/408 computed
# 336/408 computed
# 337/408 computed
# 338/408 computed
# 339/408 computed
# 340/408 computed
# 341/408 computed
# 342/408 computed
# 343/408 computed
# 344/408 computed
# 345/408 computed
# 346/408 computed
# 347/408 computed
# 348/408 computed
# 349/408 computed
# 350/408 computed
# 351/408 computed
# 352/408 computed
# 353/408 computed
# 354/408 computed
# 355/408 computed
# 356/408 computed
# 357/408 computed
# 358/408 computed
# 359/408 computed
# 360/408 computed
# 361/408 computed
# 362/408 computed
# 363/408 computed
# 364/408 computed
# 365/408 computed
# 366/408 computed
# 367/408 computed
# 368/408 computed
# 369/408 computed
# 370/408 computed
# 371/408 computed
# 372/408 computed
# 373/408 computed
# 374/408 computed
# 375/408 computed
# 376/408 computed
# 377/408 computed
# 378/408 computed
# 379/408 computed
# 380/408 computed
# 381/408 computed
# 382/408 computed
# 383/408 computed
# 384/408 computed
# 385/408 computed
# 386/408 computed
# 387/408 computed
# 388/408 computed
# 389/408 computed
# 390/408 computed
# 391/408 computed
# 392/408 computed
# 393/408 computed
# 394/408 computed
# 395/408 computed
# 396/408 computed
# 397/408 computed
# 398/408 computed
# 399/408 computed
# 400/408 computed
# 401/408 computed
# 402/408 computed
# 403/408 computed
# 404/408 computed
# 405/408 computed
# 406/408 computed
# 407/408 computed

# %%
with open(MAIN_PATH + "start_data.pickle", 'wb') as f:
  pickle.dump(data, f)
print("Data seved")

with open(MAIN_PATH + "start_labels.pickle", 'wb') as f:
  pickle.dump(labels, f)
print("Labels seved")

# %%
"""print(data[0].shape)
for i, d in enumerate(data):
  data[i] = np.resize(d, (int(512 // COMPRESSION), int(512 // COMPRESSION), min_height, 1))"""

data = np.array(data, dtype="float")
labels = np.array(labels)

# %%
(trainX, testX, trainY, testY) = train_test_split(data, labels,
                                                  test_size=0.10,
                                                  random_state=48)

print("Dataset prepared")
# Out:
# Dataset prepared

# %%
print(trainX[0].shape)
# Out:
# (128, 128, 32, 1)

# %% [markdown]
# ### АРХИТЕКТУРЫ

# %%
from keras.layers import Conv3D, Flatten, Dropout, Activation, MaxPooling3D, MaxPooling2D

model = Sequential() 

model.add(Conv3D(32, (3, 3, 3), padding="same", input_shape=(int(512 // COMPRESSION), int(512 // COMPRESSION), trainX[0].shape[2], 1)))
model.add(Activation("relu"))
model.add(Conv3D(32, (3, 3, 3), padding="same", activation="relu"))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(Dropout(0.25))

model.add(Conv3D(64, (3, 3, 3), padding="same", activation="relu"))
model.add(Conv3D(64, (3, 3, 3), padding="same", activation="relu"))

model.add(MaxPooling3D(pool_size = (2, 2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())

#model.add(Dense(1024,input_shape=(3072,), activation='sigmoid'))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))

# %% [markdown]
# Принципиально новая архитектура (нет)

# %%
from keras.layers import Conv3D, Flatten, Dropout, Activation, MaxPool3D, MaxPooling2D, GlobalAveragePooling3D
from tensorflow.keras.layers import BatchNormalization



model = Sequential() 
model.add(Conv3D(filters=32, kernel_size=3, padding="same", activation='relu', input_shape=(int(512 // COMPRESSION), int(512 // COMPRESSION), trainX[0].shape[2], 1)))
model.add(MaxPool3D(pool_size=2))
model.add(BatchNormalization())

model.add(Conv3D(filters=64, kernel_size=3, padding="same", activation='relu'))
model.add(MaxPool3D(pool_size=2))
model.add(BatchNormalization())

model.add(Conv3D(filters=128, kernel_size=3, padding="same", activation='relu'))
model.add(MaxPool3D(pool_size=2))
model.add(BatchNormalization())

model.add(Conv3D(filters=256, kernel_size=3, padding="same", activation='relu'))
model.add(MaxPool3D(pool_size=2))
model.add(BatchNormalization())

model.add(GlobalAveragePooling3D())
model.add(Dense(units=512, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(units=2, activation='sigmoid'))

# %%
from keras.layers import Conv3D, Flatten, Dropout, Activation, MaxPooling3D, MaxPooling2D, AveragePooling3D
from tensorflow.keras.layers import BatchNormalization
model = Sequential()

model.add(Conv3D(32, 5, padding="same", input_shape=(int(512 // COMPRESSION), int(512 // COMPRESSION), trainX[0].shape[2], 1), activation="relu"))
model.add(AveragePooling3D(pool_size=(2, 2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Conv3D(32, 5, padding="same", activation="relu"))
model.add(AveragePooling3D(pool_size=(2, 2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Conv3D(32, 5, padding="same", activation="relu"))
model.add(AveragePooling3D(pool_size=(2, 2, 2)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(512, activation="sigmoid"))
model.add(Dropout(0.5))
model.add(Dense(256, activation="sigmoid"))
model.add(Dropout(0.5))
model.add(Dense(128, activation="sigmoid"))
model.add(Dropout(0.5))
model.add(Dense(2, activation="sigmoid"))

# %%
from keras.layers import Conv3D, Flatten, Dropout, Activation, MaxPooling3D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization


model = Sequential()

chanDim = -1
model.add(Conv3D(8, 16, strides=1, padding='same', activation='relu',
                 kernel_initializer='glorot_normal',
                 input_shape=(128, 128, trainX[0].shape[2], 1)))

model.add(Conv3D(16, 9, strides=1, padding='same', activation='relu',
                 kernel_initializer='glorot_normal'))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(Dropout(0.1))

model.add(Conv3D(8, 9, strides=1, padding='same', activation='relu',
                 kernel_initializer='glorot_normal'))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(Dropout(0.1))

model.add(Flatten())
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.1))

model.add(Dense(2, activation='sigmoid'))

print ("End")
# Out:
# End

# %%
from keras.layers import Conv3D, Flatten, Dropout, Activation, MaxPooling3D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization

model = Sequential()

chanDim = -1
model.add(Conv3D(8, (5, 5, 5), padding="same",
          input_shape=(int(512 // COMPRESSION), int(512 // COMPRESSION), trainX[0].shape[2], 1)))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))

model.add(Conv3D(16, (5, 5, 5), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(Conv3D(16, (5, 5, 5), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(Dropout(0.1))

model.add(Conv3D(32, (7, 7, 7), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(Conv3D(32, (7, 7, 7), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(Dropout(0.1))


model.add(Conv3D(64, (9, 9, 9), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(Conv3D(64, (9, 9, 9), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(Dropout(0.1))

model.add(Flatten())
model.add(Dense(256))
model.add(Activation("relu"))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128))
model.add(Activation("relu"))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation("relu"))
model.add(Dropout(0.25))

model.add(Dense(2))
model.add(Activation("softmax"))

print ("End")
# Out:
# End

# %%
from keras.layers import Conv3D, Flatten, Dropout, Activation, MaxPooling3D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization

model = Sequential()

chanDim = -1
model.add(Conv3D(32, 5, strides=4, padding='same', activation='relu',
                 input_shape=(int(512 // COMPRESSION), int(512 // COMPRESSION), trainX[0].shape[2], 1)))
model.add(Conv3D(32, 5, padding='same', activation='relu'))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(Dropout(0.5))
  
model.add(Conv3D(64, 3, strides=1, padding='same', activation='sigmoid'))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(Conv3D(64, 3, strides=1, padding='same', activation='sigmoid'))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling3D(pool_size=(2, 2, 2)))
model.add(Conv3D(64, 3, strides=1, padding='same', activation='sigmoid'))
model.add(BatchNormalization(axis=chanDim))
model.add(Dropout(0.5))
  
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.15))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.15))
  
model.add(Dense(2, activation='softmax'))

print('End')

# %%
from keras.layers import Conv3D, Flatten, Dropout, Activation, MaxPooling3D, MaxPooling2D, MaxPool3D
from tensorflow.keras.layers import BatchNormalization

chanDim = -1
model = Sequential()
model.add(Conv3D(32 , 8 , strides=4, padding = 'same' , activation = 'relu' , input_shape=(int(512 // COMPRESSION), int(512 // COMPRESSION), trainX[0].shape[2], 1)))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPool3D(pool_size = (2,2, 2)))
model.add(Conv3D(64 , 16 , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.1))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPool3D(pool_size=(2,2,2), strides = 2 , padding = 'same'))
model.add(Conv3D(64 , 3 , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPool3D(pool_size=(2,2,2), strides = 2 , padding = 'same'))
model.add(Conv3D(128 , 3 , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPool3D(pool_size=(2,2,2), strides = 2 , padding = 'same'))
model.add(Conv3D(256 , 3 , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPool3D(pool_size=(2,2,2), strides = 2 , padding = 'same'))
model.add(Flatten())
model.add(Dense(512 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(512 , activation = 'relu'))
model.add(Dropout(0.2))

model.add(Dense(2 , activation = 'sigmoid'))
model.compile(optimizer = "rmsprop" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model.summary()

# %% [markdown]
# ### ОБУЧЕНИЕ

# %%
from keras.optimizers import Adam, RMSprop

EPOCHS = 50

INIT_LR = 0.003

#opt = SGD(lr=INIT_LR, decay=1e-7)

BS = 32

opt = Adam(lr=INIT_LR, decay=INIT_LR / (EPOCHS * 0.5))

#opt = Adam(learning_rate=INIT_LR, beta_1=0.9, beta_2=0.999, amsgrad=False)
#opt = RMSprop(learning_rate=0.001, rho=0.9)

model.compile(loss="binary_crossentropy", optimizer=opt,
              metrics=["accuracy"])  #categorial_crosentropy

print ("Model compiled")
model.summary()
# Out:
# Model compiled
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_8 (Conv3D)            (None, 128, 128, 32, 32)  896
# _________________________________________________________________
# max_pooling3d_8 (MaxPooling3 (None, 64, 64, 16, 32)    0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64, 64, 16, 32)    128
# _________________________________________________________________
# conv3d_9 (Conv3D)            (None, 64, 64, 16, 64)    55360
# _________________________________________________________________
# max_pooling3d_9 (MaxPooling3 (None, 32, 32, 8, 64)     0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 32, 32, 8, 64)     256
# _________________________________________________________________
# conv3d_10 (Conv3D)           (None, 32, 32, 8, 128)    221312
# _________________________________________________________________
# max_pooling3d_10 (MaxPooling (None, 16, 16, 4, 128)    0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 16, 16, 4, 128)    512
# _________________________________________________________________
# conv3d_11 (Conv3D)           (None, 16, 16, 4, 256)    884992
# _________________________________________________________________
# max_pooling3d_11 (MaxPooling (None, 8, 8, 2, 256)      0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 8, 8, 2, 256)      1024
# _________________________________________________________________
# global_average_pooling3d_2 ( (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               131584
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 1,297,090
# Trainable params: 1,296,130
# Non-trainable params: 960
# _________________________________________________________________

# %%
from keras.models import load_model
model = load_model(MAIN_PATH + "THE_BEST_RESULT__3.h5")
BS = 32
EPOCHS = 50

# %%
checkpointer = ModelCheckpoint(filepath=MAIN_PATH + '/THE_BEST_RESULT__3_2.h5', verbose=1, save_best_only=True)

print(trainX[0].shape)
H = None
H = model.fit(trainX, trainY, validation_data=(testX, testY),
              steps_per_epoch=trainX.shape[0] // BS,
              epochs=EPOCHS, batch_size=BS,
              shuffle=True,
              callbacks=[checkpointer])

print("Model trained")
# Out:
# (128, 128, 32, 1)
# Epoch 1/50
# 11/11 [==============================] - 10s 805ms/step - loss: 0.6930 - accuracy: 0.5317 - val_loss: 0.6946 - val_accuracy: 0.4146
#
# Epoch 00001: val_loss improved from inf to 0.69455, saving model to /content/drive/My Drive/Dataset/THE_BEST_RESULT__3_2.h5
# Epoch 2/50
# 11/11 [==============================] - 8s 794ms/step - loss: 0.6935 - accuracy: 0.4852 - val_loss: 0.6945 - val_accuracy: 0.4146
#
# Epoch 00002: val_loss improved from 0.69455 to 0.69453, saving model to /content/drive/My Drive/Dataset/THE_BEST_RESULT__3_2.h5
# Epoch 3/50
# 11/11 [==============================] - 8s 755ms/step - loss: 0.6937 - accuracy: 0.4667 - val_loss: 0.6941 - val_accuracy: 0.4146
#
# Epoch 00003: val_loss improved from 0.69453 to 0.69411, saving model to /content/drive/My Drive/Dataset/THE_BEST_RESULT__3_2.h5
# Epoch 4/50
# 11/11 [==============================] - 8s 749ms/step - loss: 0.6930 - accuracy: 0.5192 - val_loss: 0.6942 - val_accuracy: 0.4146
#
# Epoch 00004: val_loss did not improve from 0.69411
# Epoch 5/50
# 11/11 [==============================] - 8s 739ms/step - loss: 0.6932 - accuracy: 0.4965 - val_loss: 0.6948 - val_accuracy: 0.4146
#
# Epoch 00005: val_loss did not improve from 0.69411
# Epoch 6/50
# 11/11 [==============================] - 8s 738ms/step - loss: 0.6944 - accuracy: 0.4357 - val_loss: 0.6943 - val_accuracy: 0.4146
#
# Epoch 00006: val_loss did not improve from 0.69411
# Epoch 7/50
# 11/11 [==============================] - 8s 738ms/step - loss: 0.6919 - accuracy: 0.5963 - val_loss: 0.6947 - val_accuracy: 0.4146
#
# Epoch 00007: val_loss did not improve from 0.69411
# Epoch 8/50
# 11/11 [==============================] - 8s 737ms/step - loss: 0.6937 - accuracy: 0.4757 - val_loss: 0.6950 - val_accuracy: 0.4146
#
# Epoch 00008: val_loss did not improve from 0.69411
# Epoch 9/50
# 11/11 [==============================] - 8s 738ms/step - loss: 0.6932 - accuracy: 0.5008 - val_loss: 0.6950 - val_accuracy: 0.4146
#
# Epoch 00009: val_loss did not improve from 0.69411
# Epoch 10/50
# 11/11 [==============================] - 8s 740ms/step - loss: 0.6930 - accuracy: 0.5124 - val_loss: 0.6953 - val_accuracy: 0.4146
#
# Epoch 00010: val_loss did not improve from 0.69411
# Epoch 11/50
# 11/11 [==============================] - 8s 740ms/step - loss: 0.6927 - accuracy: 0.5252 - val_loss: 0.6958 - val_accuracy: 0.4146
#
# Epoch 00011: val_loss did not improve from 0.69411
# Epoch 12/50
# 11/11 [==============================] - 8s 744ms/step - loss: 0.6936 - accuracy: 0.4904 - val_loss: 0.6960 - val_accuracy: 0.4146
#
# Epoch 00012: val_loss did not improve from 0.69411
# Epoch 13/50
# 11/11 [==============================] - 9s 781ms/step - loss: 0.6937 - accuracy: 0.4864 - val_loss: 0.6957 - val_accuracy: 0.4146
#
# Epoch 00013: val_loss did not improve from 0.69411
# Epoch 14/50
# 11/11 [==============================] - 8s 778ms/step - loss: 0.6924 - accuracy: 0.5307 - val_loss: 0.6962 - val_accuracy: 0.4146
#
# Epoch 00014: val_loss did not improve from 0.69411
# Epoch 15/50
# 11/11 [==============================] - 8s 738ms/step - loss: 0.6926 - accuracy: 0.5204 - val_loss: 0.6963 - val_accuracy: 0.4146
#
# Epoch 00015: val_loss did not improve from 0.69411
# Epoch 16/50
# 11/11 [==============================] - 8s 738ms/step - loss: 0.6931 - accuracy: 0.5048 - val_loss: 0.6964 - val_accuracy: 0.4146
#
# Epoch 00016: val_loss did not improve from 0.69411
# Epoch 17/50
# 11/11 [==============================] - 8s 740ms/step - loss: 0.6937 - accuracy: 0.4877 - val_loss: 0.6957 - val_accuracy: 0.4146
#
# Epoch 00017: val_loss did not improve from 0.69411
# Epoch 18/50
# 11/11 [==============================] - 8s 739ms/step - loss: 0.6921 - accuracy: 0.5390 - val_loss: 0.6960 - val_accuracy: 0.4146
#
# Epoch 00018: val_loss did not improve from 0.69411
# Epoch 19/50
# 11/11 [==============================] - 8s 738ms/step - loss: 0.6926 - accuracy: 0.5216 - val_loss: 0.6961 - val_accuracy: 0.4146
#
# Epoch 00019: val_loss did not improve from 0.69411
# Epoch 20/50
# 11/11 [==============================] - 8s 738ms/step - loss: 0.6925 - accuracy: 0.5237 - val_loss: 0.6964 - val_accuracy: 0.4146
#
# Epoch 00020: val_loss did not improve from 0.69411
# Epoch 21/50
# 11/11 [==============================] - 8s 742ms/step - loss: 0.6938 - accuracy: 0.4875 - val_loss: 0.6967 - val_accuracy: 0.4146
#
# Epoch 00021: val_loss did not improve from 0.69411
# Epoch 22/50
# 11/11 [==============================] - 8s 742ms/step - loss: 0.6935 - accuracy: 0.4964 - val_loss: 0.6969 - val_accuracy: 0.4146
#
# Epoch 00022: val_loss did not improve from 0.69411
# Epoch 23/50
# 11/11 [==============================] - 8s 740ms/step - loss: 0.6940 - accuracy: 0.4843 - val_loss: 0.6968 - val_accuracy: 0.4146
#
# Epoch 00023: val_loss did not improve from 0.69411
# Epoch 24/50
# 11/11 [==============================] - 8s 743ms/step - loss: 0.6926 - accuracy: 0.5187 - val_loss: 0.6964 - val_accuracy: 0.4146
#
# Epoch 00024: val_loss did not improve from 0.69411
# Epoch 25/50
# 11/11 [==============================] - 9s 779ms/step - loss: 0.6929 - accuracy: 0.5140 - val_loss: 0.6964 - val_accuracy: 0.4146
#
# Epoch 00025: val_loss did not improve from 0.69411
# Epoch 26/50
# 11/11 [==============================] - 8s 778ms/step - loss: 0.6920 - accuracy: 0.5354 - val_loss: 0.6966 - val_accuracy: 0.4146
#
# Epoch 00026: val_loss did not improve from 0.69411
# Epoch 27/50
# 11/11 [==============================] - 8s 741ms/step - loss: 0.6929 - accuracy: 0.5114 - val_loss: 0.6968 - val_accuracy: 0.4146
#
# Epoch 00027: val_loss did not improve from 0.69411
# Epoch 28/50
# 11/11 [==============================] - 8s 740ms/step - loss: 0.6952 - accuracy: 0.4534 - val_loss: 0.6963 - val_accuracy: 0.4146
#
# Epoch 00028: val_loss did not improve from 0.69411
# Epoch 29/50
# 11/11 [==============================] - 8s 742ms/step - loss: 0.6923 - accuracy: 0.5288 - val_loss: 0.6964 - val_accuracy: 0.4146
#
# Epoch 00029: val_loss did not improve from 0.69411
# Epoch 30/50
# 11/11 [==============================] - 8s 742ms/step - loss: 0.6941 - accuracy: 0.4790 - val_loss: 0.6961 - val_accuracy: 0.4146
#
# Epoch 00030: val_loss did not improve from 0.69411
# Epoch 31/50
# 11/11 [==============================] - 8s 739ms/step - loss: 0.6912 - accuracy: 0.5656 - val_loss: 0.6960 - val_accuracy: 0.4146
#
# Epoch 00031: val_loss did not improve from 0.69411
# Epoch 32/50
# 11/11 [==============================] - 8s 741ms/step - loss: 0.6928 - accuracy: 0.5148 - val_loss: 0.6960 - val_accuracy: 0.4146
#
# Epoch 00032: val_loss did not improve from 0.69411
# Epoch 33/50
# 11/11 [==============================] - 8s 740ms/step - loss: 0.6923 - accuracy: 0.5320 - val_loss: 0.6963 - val_accuracy: 0.4146
#
# Epoch 00033: val_loss did not improve from 0.69411
# Epoch 34/50
# 11/11 [==============================] - 8s 737ms/step - loss: 0.6938 - accuracy: 0.4860 - val_loss: 0.6964 - val_accuracy: 0.4146
#
# Epoch 00034: val_loss did not improve from 0.69411
# Epoch 35/50
# 11/11 [==============================] - 8s 738ms/step - loss: 0.6927 - accuracy: 0.5185 - val_loss: 0.6966 - val_accuracy: 0.4146
#
# Epoch 00035: val_loss did not improve from 0.69411
# Epoch 36/50
# 11/11 [==============================] - 8s 739ms/step - loss: 0.6925 - accuracy: 0.5219 - val_loss: 0.6966 - val_accuracy: 0.4146
#
# Epoch 00036: val_loss did not improve from 0.69411
# Epoch 37/50
# 11/11 [==============================] - 9s 777ms/step - loss: 0.6932 - accuracy: 0.5046 - val_loss: 0.6966 - val_accuracy: 0.4146
#
# Epoch 00037: val_loss did not improve from 0.69411
# Epoch 38/50
# 11/11 [==============================] - 8s 775ms/step - loss: 0.6918 - accuracy: 0.5411 - val_loss: 0.6968 - val_accuracy: 0.4146
#
# Epoch 00038: val_loss did not improve from 0.69411
# Epoch 39/50
# 11/11 [==============================] - 8s 749ms/step - loss: 0.6932 - accuracy: 0.5048 - val_loss: 0.6967 - val_accuracy: 0.4146
#
# Epoch 00039: val_loss did not improve from 0.69411
# Epoch 40/50
# 11/11 [==============================] - 8s 742ms/step - loss: 0.6935 - accuracy: 0.4967 - val_loss: 0.6965 - val_accuracy: 0.4146
#
# Epoch 00040: val_loss did not improve from 0.69411
# Epoch 41/50
# 11/11 [==============================] - 8s 743ms/step - loss: 0.6926 - accuracy: 0.5192 - val_loss: 0.6967 - val_accuracy: 0.4146
#
# Epoch 00041: val_loss did not improve from 0.69411
# Epoch 42/50
# 11/11 [==============================] - 8s 739ms/step - loss: 0.6937 - accuracy: 0.4914 - val_loss: 0.6966 - val_accuracy: 0.4146
#
# Epoch 00042: val_loss did not improve from 0.69411
# Epoch 43/50
# 11/11 [==============================] - 8s 738ms/step - loss: 0.6915 - accuracy: 0.5489 - val_loss: 0.6968 - val_accuracy: 0.4146
#
# Epoch 00043: val_loss did not improve from 0.69411
# Epoch 44/50
# 11/11 [==============================] - 8s 742ms/step - loss: 0.6928 - accuracy: 0.5159 - val_loss: 0.6970 - val_accuracy: 0.4146
#
# Epoch 00044: val_loss did not improve from 0.69411
# Epoch 45/50
# 11/11 [==============================] - 8s 739ms/step - loss: 0.6909 - accuracy: 0.5593 - val_loss: 0.6971 - val_accuracy: 0.4146
#
# Epoch 00045: val_loss did not improve from 0.69411
# Epoch 46/50
# 11/11 [==============================] - 8s 740ms/step - loss: 0.6925 - accuracy: 0.5206 - val_loss: 0.6967 - val_accuracy: 0.4146
#
# Epoch 00046: val_loss did not improve from 0.69411
# Epoch 47/50
# 11/11 [==============================] - 8s 741ms/step - loss: 0.6918 - accuracy: 0.5383 - val_loss: 0.6967 - val_accuracy: 0.4146
#
# Epoch 00047: val_loss did not improve from 0.69411
# Epoch 48/50
# 11/11 [==============================] - 8s 744ms/step - loss: 0.6924 - accuracy: 0.5244 - val_loss: 0.6965 - val_accuracy: 0.4146
#
# Epoch 00048: val_loss did not improve from 0.69411
# Epoch 49/50
# 11/11 [==============================] - 9s 778ms/step - loss: 0.6928 - accuracy: 0.5146 - val_loss: 0.6963 - val_accuracy: 0.4146
#
# Epoch 00049: val_loss did not improve from 0.69411
# Epoch 50/50
# 11/11 [==============================] - 8s 781ms/step - loss: 0.6907 - accuracy: 0.5730 - val_loss: 0.6969 - val_accuracy: 0.4146
#
# Epoch 00050: val_loss did not improve from 0.69411
# Model trained

# %%
N = np.arange(0, EPOCHS)
plt.style.use("seaborn-dark-palette")
plt.figure()
plt.plot(N, H.history["loss"], label="train_loss")
plt.plot(N, H.history["val_loss"], label="val_loss")
plt.title("Results")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()
plt.savefig(MAIN_PATH + "Loss6.png")

plt.style.use("seaborn-dark-palette")
plt.figure()
plt.plot(N, H.history["accuracy"], label="train_acc")
plt.plot(N, H.history["val_accuracy"], label="val_acc")
plt.title("Results")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend()
plt.savefig(MAIN_PATH + "Accuracy6.png")


print("End")
# Out:
# End

# %%
model.save(MAIN_PATH + "Лучшая модель 71 процент.model")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Dataset/Лучшая модель 71 процент.model/assets
